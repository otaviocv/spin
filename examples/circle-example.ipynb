# %% [markdown]
# # Circle Example

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import matplotlib.pyplot as plt

import sys
sys.path.append("../spin/")

# %matplotlib inline

# %%
from spin import l2_distance_matrix, side_to_side

# %% [markdown]
# ## Generating Data

# %%
n_points = 100

# %%
r_coords = np.random.normal(1, 0.1, size=n_points)
t_coords = np.random.uniform(0, 2*np.pi, size=n_points)

# %%
x_coords = r_coords * np.cos(t_coords)
y_coords = r_coords * np.sin(t_coords)

# %% [markdown]
# ### Visualizing data

# %%
f, ax = plt.subplots(figsize=(5, 5), dpi=100)
ax.scatter(x_coords, y_coords, s=.8)

# %%
points = np.array([x_coords, y_coords])

# %% [markdown]
# ### Distance Matrix

# %%
# %%time
distances = l2_distance_matrix(points, points)
# Out:
# CPU times: user 1.51 ms, sys: 121 µs, total: 1.63 ms
# Wall time: 407 µs

# %%
f, ax = plt.subplots(figsize=(5, 5), dpi=100)
ax.matshow(distances, cmap="plasma")

# %% [markdown]
# ## Side to Side SPIN

# %%
# %%time
incr_vector = np.array([i-(n_points+1)/2 for i in range(n_points)])
permutation = side_to_side(distances, incr_vector, 10000000)
# Out:
# CPU times: user 19min 19s, sys: 2min 49s, total: 22min 8s
# Wall time: 18min 53s

# %%
ordered_distances = permutation.dot(distances).dot(permutation.T)

# %%
f, ax = plt.subplots(figsize=(5, 5), dpi=100)
ax.matshow(a, cmap="plasma")
